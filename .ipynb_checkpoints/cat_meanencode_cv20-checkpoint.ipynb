# %%
from catboost import CatBoostClassifier, Pool, cv
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from xgboost import XGBClassifier
from train_val_split import train_validation_split
import ggplot as gplt
from tools.mean_encoder import *
# Out:
# C:\Users\S\Anaconda3\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# C:\Users\S\Anaconda3\lib\site-packages\ggplot\stats\smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# C:\Users\S\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
train_set = pd.read_csv("dataset/train_val/training_set.csv")
test_set = pd.read_csv("dataset/train_val/testing_set.csv")

y_train = train_set["deal_or_not"]
for table in [train_set, test_set]:
    table.drop(columns=["deal_or_not", "group_id", "order_id"], inplace=True)
    
#and "DoY" not in col
cat_feature = []
key_words = ["source", "unit", "sub", "area", "order", "begin", "_airport",
             "abroad", "home"]
for i, col in enumerate(train_set.columns):
    for kw in key_words:
        if kw in col and "duration" not in col and "DoY" not in col and i not in cat_feature:
            cat_feature.append(i)

cv = StratifiedKFold(20, shuffle=True, random_state=851206)
mean_enc_col = ["source1_unit"] # 這個column是catboost feature importance最高的feature
train_set = mean_encoder(train_set, y_train, mean_enc_col, "deal_or_not", cv)
test_set = test_set_encoder(train_set, y_train, test_set, mean_enc_col, "deal_or_not")
# Out:
# C:\Users\S\travel_data\tools\mean_encoder.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   x_val[colname] = means

# %%
param = {"objective": "binary:logistic",
             "max_depth": 6,
             "eta": 0.05,
             "n_estimators": 200,
             "silent": True,
             "tree_method": "gpu_hist",
             "seed": 104702016
             }
#dtrain = xgb.DMatrix(train_set, label=train_y)
xgb_nocat = XGBClassifier(**param)
xgb_nocat.fit(train_set, y_train, eval_metric="auc", verbose=True)
xgb_prob = xgb_nocat.predict_proba(test_set)
xgb_output = pd.read_csv("testing-set.csv")
xgb_output["deal_or_not"] = xgb_prob[:, 1]
xgb_output.to_csv("xgb_meanencode.csv", encoding="utf-8", index=False)

# %%
train_set.fillna("NaN", inplace=True)
test_set.fillna("NaN", inplace=True)

cat_cat = CatBoostClassifier(
    learning_rate=0.05,
    iterations=500,
    random_seed=104702016,
    eval_metric = 'AUC',
    counter_calc_method='SkipTest',
    one_hot_max_size=255
)
cat_cat.fit(
    train_set, y_train,
    cat_features=cat_feature,
    logging_level='Verbose',
)
cat_pred = cat_cat.predict_proba(test_set)
cat_output = pd.read_csv("testing-set.csv")
cat_output["deal_or_not"] = cat_pred[:, 1]
cat_output.to_csv("cat_meanencode_cv20.csv", encoding="utf-8", index=False)
# Out:
# 0:	total: 327ms	remaining: 2m 42s
# 1:	total: 508ms	remaining: 2m 6s
# 2:	total: 685ms	remaining: 1m 53s
# 3:	total: 810ms	remaining: 1m 40s
# 4:	total: 1s	remaining: 1m 39s
# 5:	total: 1.15s	remaining: 1m 34s
# 6:	total: 1.27s	remaining: 1m 29s
# 7:	total: 1.42s	remaining: 1m 27s
# 8:	total: 1.57s	remaining: 1m 25s
# 9:	total: 1.73s	remaining: 1m 24s
# 10:	total: 1.88s	remaining: 1m 23s
# 11:	total: 2.03s	remaining: 1m 22s
# 12:	total: 2.14s	remaining: 1m 20s
# 13:	total: 2.28s	remaining: 1m 19s
# 14:	total: 2.46s	remaining: 1m 19s
# 15:	total: 2.61s	remaining: 1m 19s
# 16:	total: 2.78s	remaining: 1m 18s
# 17:	total: 2.93s	remaining: 1m 18s
# 18:	total: 3.09s	remaining: 1m 18s
# 19:	total: 3.24s	remaining: 1m 17s
# 20:	total: 3.37s	remaining: 1m 16s
# 21:	total: 3.51s	remaining: 1m 16s
# 22:	total: 3.67s	remaining: 1m 16s
# 23:	total: 3.81s	remaining: 1m 15s
# 24:	total: 3.97s	remaining: 1m 15s
# 25:	total: 4.11s	remaining: 1m 14s
# 26:	total: 4.29s	remaining: 1m 15s
# 27:	total: 4.43s	remaining: 1m 14s
# 28:	total: 4.61s	remaining: 1m 14s
# 29:	total: 4.75s	remaining: 1m 14s
# 30:	total: 4.94s	remaining: 1m 14s
# 31:	total: 5.08s	remaining: 1m 14s
# 32:	total: 5.25s	remaining: 1m 14s
# 33:	total: 5.41s	remaining: 1m 14s
# 34:	total: 5.56s	remaining: 1m 13s
# 35:	total: 5.71s	remaining: 1m 13s
# 36:	total: 5.89s	remaining: 1m 13s
# 37:	total: 6.03s	remaining: 1m 13s
# 38:	total: 6.19s	remaining: 1m 13s
# 39:	total: 6.35s	remaining: 1m 13s
# 40:	total: 6.5s	remaining: 1m 12s
# 41:	total: 6.65s	remaining: 1m 12s
# 42:	total: 6.82s	remaining: 1m 12s
# 43:	total: 6.94s	remaining: 1m 11s
# 44:	total: 7.11s	remaining: 1m 11s
# 45:	total: 7.26s	remaining: 1m 11s
# 46:	total: 7.43s	remaining: 1m 11s
# 47:	total: 7.58s	remaining: 1m 11s
# 48:	total: 7.75s	remaining: 1m 11s
# 49:	total: 7.9s	remaining: 1m 11s
# 50:	total: 8.08s	remaining: 1m 11s
# 51:	total: 8.25s	remaining: 1m 11s
# 52:	total: 8.42s	remaining: 1m 11s
# 53:	total: 8.58s	remaining: 1m 10s
# 54:	total: 8.75s	remaining: 1m 10s
# 55:	total: 8.89s	remaining: 1m 10s
# 56:	total: 9.06s	remaining: 1m 10s
# 57:	total: 9.21s	remaining: 1m 10s
# 58:	total: 9.41s	remaining: 1m 10s
# 59:	total: 9.55s	remaining: 1m 10s
# 60:	total: 9.72s	remaining: 1m 9s
# 61:	total: 9.87s	remaining: 1m 9s
# 62:	total: 10.1s	remaining: 1m 9s
# 63:	total: 10.2s	remaining: 1m 9s
# 64:	total: 10.4s	remaining: 1m 9s
# 65:	total: 10.5s	remaining: 1m 9s
# 66:	total: 10.7s	remaining: 1m 8s
# 67:	total: 10.8s	remaining: 1m 8s
# 68:	total: 11s	remaining: 1m 8s
# 69:	total: 11.2s	remaining: 1m 8s
# 70:	total: 11.3s	remaining: 1m 8s
# 71:	total: 11.5s	remaining: 1m 8s
# 72:	total: 11.6s	remaining: 1m 7s
# 73:	total: 11.7s	remaining: 1m 7s
# 74:	total: 11.9s	remaining: 1m 7s
# 75:	total: 12.1s	remaining: 1m 7s
# 76:	total: 12.2s	remaining: 1m 7s
# 77:	total: 12.4s	remaining: 1m 6s
# 78:	total: 12.5s	remaining: 1m 6s
# 79:	total: 12.6s	remaining: 1m 6s
# 80:	total: 12.8s	remaining: 1m 5s
# 81:	total: 12.9s	remaining: 1m 5s
# 82:	total: 13.1s	remaining: 1m 5s
# 83:	total: 13.2s	remaining: 1m 5s
# 84:	total: 13.3s	remaining: 1m 5s
# 85:	total: 13.5s	remaining: 1m 4s
# 86:	total: 13.7s	remaining: 1m 4s
# 87:	total: 13.8s	remaining: 1m 4s
# 88:	total: 14s	remaining: 1m 4s
# 89:	total: 14.1s	remaining: 1m 4s
# 90:	total: 14.3s	remaining: 1m 4s
# 91:	total: 14.4s	remaining: 1m 4s
# 92:	total: 14.6s	remaining: 1m 3s
# 93:	total: 14.8s	remaining: 1m 3s
# 94:	total: 14.9s	remaining: 1m 3s
# 95:	total: 15s	remaining: 1m 3s
# 96:	total: 15.2s	remaining: 1m 3s
# 97:	total: 15.3s	remaining: 1m 2s
# 98:	total: 15.5s	remaining: 1m 2s
# 99:	total: 15.6s	remaining: 1m 2s
# 100:	total: 15.8s	remaining: 1m 2s
# 101:	total: 15.9s	remaining: 1m 2s
# 102:	total: 16.1s	remaining: 1m 1s
# 103:	total: 16.2s	remaining: 1m 1s
# 104:	total: 16.4s	remaining: 1m 1s
# 105:	total: 16.5s	remaining: 1m 1s
# 106:	total: 16.6s	remaining: 1m 1s
# 107:	total: 16.8s	remaining: 1m
# 108:	total: 16.9s	remaining: 1m
# 109:	total: 17.1s	remaining: 1m
# 110:	total: 17.3s	remaining: 1m
# 111:	total: 17.4s	remaining: 1m
# 112:	total: 17.6s	remaining: 1m
# 113:	total: 17.7s	remaining: 60s
# 114:	total: 17.9s	remaining: 59.9s
# 115:	total: 18s	remaining: 59.7s
# 116:	total: 18.2s	remaining: 59.6s
# 117:	total: 18.3s	remaining: 59.3s
# 118:	total: 18.5s	remaining: 59.2s
# 119:	total: 18.6s	remaining: 58.9s
# 120:	total: 18.8s	remaining: 58.8s
# 121:	total: 18.9s	remaining: 58.7s
# 122:	total: 19.1s	remaining: 58.5s
# 123:	total: 19.2s	remaining: 58.3s
# 124:	total: 19.4s	remaining: 58.1s
# 125:	total: 19.5s	remaining: 58s
# 126:	total: 19.7s	remaining: 57.8s
# 127:	total: 19.8s	remaining: 57.6s
# 128:	total: 20s	remaining: 57.4s
# 129:	total: 20.1s	remaining: 57.2s
# 130:	total: 20.3s	remaining: 57.1s
# 131:	total: 20.4s	remaining: 56.9s
# 132:	total: 20.5s	remaining: 56.7s
# 133:	total: 20.7s	remaining: 56.4s
# 134:	total: 20.8s	remaining: 56.3s
# 135:	total: 21s	remaining: 56.1s
# 136:	total: 21.1s	remaining: 56s
# 137:	total: 21.3s	remaining: 55.8s
# 138:	total: 21.4s	remaining: 55.6s
# 139:	total: 21.6s	remaining: 55.5s
# 140:	total: 21.7s	remaining: 55.4s
# 141:	total: 21.9s	remaining: 55.2s
# 142:	total: 22.1s	remaining: 55.1s
# 143:	total: 22.2s	remaining: 54.9s
# 144:	total: 22.3s	remaining: 54.7s
# 145:	total: 22.5s	remaining: 54.5s
# 146:	total: 22.6s	remaining: 54.4s
# 147:	total: 22.8s	remaining: 54.2s
# 148:	total: 22.9s	remaining: 54s
# 149:	total: 23.1s	remaining: 53.8s
# 150:	total: 23.2s	remaining: 53.7s
# 151:	total: 23.4s	remaining: 53.5s
# 152:	total: 23.6s	remaining: 53.4s
# 153:	total: 23.7s	remaining: 53.3s
# 154:	total: 23.9s	remaining: 53.1s
# 155:	total: 24s	remaining: 52.9s
# 156:	total: 24.2s	remaining: 52.8s
# 157:	total: 24.3s	remaining: 52.6s
# 158:	total: 24.5s	remaining: 52.5s
# 159:	total: 24.6s	remaining: 52.3s
# 160:	total: 24.7s	remaining: 52.1s
# 161:	total: 24.9s	remaining: 51.9s
# 162:	total: 25s	remaining: 51.8s
# 163:	total: 25.2s	remaining: 51.6s
# 164:	total: 25.4s	remaining: 51.5s
# 165:	total: 25.5s	remaining: 51.3s
# 166:	total: 25.6s	remaining: 51.1s
# 167:	total: 25.8s	remaining: 50.9s
# 168:	total: 25.9s	remaining: 50.8s
# 169:	total: 26.1s	remaining: 50.6s
# 170:	total: 26.2s	remaining: 50.5s
# 171:	total: 26.4s	remaining: 50.3s
# 172:	total: 26.6s	remaining: 50.2s
# 173:	total: 26.7s	remaining: 50s
# 174:	total: 26.8s	remaining: 49.8s
# 175:	total: 27s	remaining: 49.7s
# 176:	total: 27.2s	remaining: 49.5s
# 177:	total: 27.3s	remaining: 49.4s
# 178:	total: 27.4s	remaining: 49.2s
# 179:	total: 27.6s	remaining: 49.1s
# 180:	total: 27.7s	remaining: 48.9s
# 181:	total: 27.9s	remaining: 48.7s
# 182:	total: 28s	remaining: 48.6s
# 183:	total: 28.2s	remaining: 48.4s
# 184:	total: 28.3s	remaining: 48.3s
# 185:	total: 28.5s	remaining: 48.1s
# 186:	total: 28.6s	remaining: 48s
# 187:	total: 28.8s	remaining: 47.8s
# 188:	total: 29s	remaining: 47.7s
# 189:	total: 29.1s	remaining: 47.5s
# 190:	total: 29.3s	remaining: 47.4s
# 191:	total: 29.4s	remaining: 47.2s
# 192:	total: 29.6s	remaining: 47.1s
# 193:	total: 29.7s	remaining: 46.9s
# 194:	total: 29.9s	remaining: 46.7s
# 195:	total: 30s	remaining: 46.6s
# 196:	total: 30.2s	remaining: 46.4s
# 197:	total: 30.3s	remaining: 46.2s
# 198:	total: 30.5s	remaining: 46.1s
# 199:	total: 30.6s	remaining: 45.9s
# 200:	total: 30.7s	remaining: 45.7s
# 201:	total: 30.9s	remaining: 45.6s
# 202:	total: 31s	remaining: 45.4s
# 203:	total: 31.2s	remaining: 45.2s
# 204:	total: 31.3s	remaining: 45.1s
# 205:	total: 31.5s	remaining: 44.9s
# 206:	total: 31.6s	remaining: 44.8s
# 207:	total: 31.8s	remaining: 44.6s
# 208:	total: 31.9s	remaining: 44.5s
# 209:	total: 32.1s	remaining: 44.3s
# 210:	total: 32.2s	remaining: 44.2s
# 211:	total: 32.4s	remaining: 44s
# 212:	total: 32.5s	remaining: 43.9s
# 213:	total: 32.7s	remaining: 43.7s
# 214:	total: 32.8s	remaining: 43.5s
# 215:	total: 33s	remaining: 43.4s
# 216:	total: 33.2s	remaining: 43.2s
# 217:	total: 33.3s	remaining: 43s
# 218:	total: 33.4s	remaining: 42.9s
# 219:	total: 33.6s	remaining: 42.7s
# 220:	total: 33.7s	remaining: 42.6s
# 221:	total: 33.9s	remaining: 42.4s
# 222:	total: 34s	remaining: 42.3s
# 223:	total: 34.2s	remaining: 42.1s
# 224:	total: 34.3s	remaining: 41.9s
# 225:	total: 34.5s	remaining: 41.8s
# 226:	total: 34.6s	remaining: 41.6s
# 227:	total: 34.8s	remaining: 41.5s
# 228:	total: 34.9s	remaining: 41.3s
# 229:	total: 35.1s	remaining: 41.2s
# 230:	total: 35.2s	remaining: 41s
# 231:	total: 35.4s	remaining: 40.9s
# 232:	total: 35.5s	remaining: 40.7s
# 233:	total: 35.7s	remaining: 40.6s
# 234:	total: 35.8s	remaining: 40.4s
# 235:	total: 36s	remaining: 40.2s
# 236:	total: 36.1s	remaining: 40.1s
# 237:	total: 36.3s	remaining: 39.9s
# 238:	total: 36.4s	remaining: 39.8s
# 239:	total: 36.6s	remaining: 39.6s
# 240:	total: 36.7s	remaining: 39.5s
# 241:	total: 36.9s	remaining: 39.3s
# 242:	total: 37s	remaining: 39.2s
# 243:	total: 37.2s	remaining: 39s
# 244:	total: 37.4s	remaining: 38.9s
# 245:	total: 37.5s	remaining: 38.7s
# 246:	total: 37.7s	remaining: 38.6s
# 247:	total: 37.8s	remaining: 38.4s
# 248:	total: 38s	remaining: 38.3s
# 249:	total: 38.2s	remaining: 38.2s
# 250:	total: 38.3s	remaining: 38s
# 251:	total: 38.5s	remaining: 37.8s
# 252:	total: 38.6s	remaining: 37.7s
# 253:	total: 38.8s	remaining: 37.6s
# 254:	total: 38.9s	remaining: 37.4s
# 255:	total: 39.1s	remaining: 37.3s
# 256:	total: 39.2s	remaining: 37.1s
# 257:	total: 39.4s	remaining: 36.9s
# 258:	total: 39.5s	remaining: 36.8s
# 259:	total: 39.7s	remaining: 36.6s
# 260:	total: 39.8s	remaining: 36.4s
# 261:	total: 39.9s	remaining: 36.3s
# 262:	total: 40.1s	remaining: 36.1s
# 263:	total: 40.2s	remaining: 36s
# 264:	total: 40.4s	remaining: 35.8s
# 265:	total: 40.5s	remaining: 35.7s
# 266:	total: 40.7s	remaining: 35.5s
# 267:	total: 40.8s	remaining: 35.3s
# 268:	total: 41s	remaining: 35.2s
# 269:	total: 41.1s	remaining: 35s
# 270:	total: 41.2s	remaining: 34.8s
# 271:	total: 41.4s	remaining: 34.7s
# 272:	total: 41.5s	remaining: 34.5s
# 273:	total: 41.7s	remaining: 34.4s
# 274:	total: 41.9s	remaining: 34.2s
# 275:	total: 42s	remaining: 34.1s
# 276:	total: 42.2s	remaining: 33.9s
# 277:	total: 42.3s	remaining: 33.8s
# 278:	total: 42.5s	remaining: 33.7s
# 279:	total: 42.7s	remaining: 33.5s
# 280:	total: 42.8s	remaining: 33.4s
# 281:	total: 42.9s	remaining: 33.2s
# 282:	total: 43.1s	remaining: 33.1s
# 283:	total: 43.3s	remaining: 32.9s
# 284:	total: 43.4s	remaining: 32.7s
# 285:	total: 43.5s	remaining: 32.6s
# 286:	total: 43.7s	remaining: 32.4s
# 287:	total: 43.8s	remaining: 32.3s
# 288:	total: 44s	remaining: 32.1s
# 289:	total: 44.1s	remaining: 31.9s
# 290:	total: 44.2s	remaining: 31.8s
# 291:	total: 44.4s	remaining: 31.6s
# 292:	total: 44.5s	remaining: 31.5s
# 293:	total: 44.7s	remaining: 31.3s
# 294:	total: 44.8s	remaining: 31.2s
# 295:	total: 45s	remaining: 31s
# 296:	total: 45.2s	remaining: 30.9s
# 297:	total: 45.3s	remaining: 30.7s
# 298:	total: 45.5s	remaining: 30.6s
# 299:	total: 45.6s	remaining: 30.4s
# 300:	total: 45.8s	remaining: 30.3s
# 301:	total: 45.9s	remaining: 30.1s
# 302:	total: 46.1s	remaining: 30s
# 303:	total: 46.3s	remaining: 29.8s
# 304:	total: 46.4s	remaining: 29.7s
# 305:	total: 46.6s	remaining: 29.5s
# 306:	total: 46.7s	remaining: 29.4s
# 307:	total: 46.9s	remaining: 29.2s
# 308:	total: 47s	remaining: 29.1s
# 309:	total: 47.2s	remaining: 28.9s
# 310:	total: 47.4s	remaining: 28.8s
# 311:	total: 47.5s	remaining: 28.6s
# 312:	total: 47.7s	remaining: 28.5s
# 313:	total: 47.8s	remaining: 28.3s
# 314:	total: 48s	remaining: 28.2s
# 315:	total: 48.1s	remaining: 28s
# 316:	total: 48.3s	remaining: 27.9s
# 317:	total: 48.4s	remaining: 27.7s
# 318:	total: 48.5s	remaining: 27.5s
# 319:	total: 48.7s	remaining: 27.4s
# 320:	total: 48.9s	remaining: 27.3s
# 321:	total: 49s	remaining: 27.1s
# 322:	total: 49.2s	remaining: 27s
# 323:	total: 49.3s	remaining: 26.8s
# 324:	total: 49.5s	remaining: 26.6s
# 325:	total: 49.6s	remaining: 26.5s
# 326:	total: 49.8s	remaining: 26.3s
# 327:	total: 49.9s	remaining: 26.2s
# 328:	total: 50.1s	remaining: 26.1s
# 329:	total: 50.3s	remaining: 25.9s
# 330:	total: 50.4s	remaining: 25.7s
# 331:	total: 50.5s	remaining: 25.6s
# 332:	total: 50.7s	remaining: 25.4s
# 333:	total: 50.8s	remaining: 25.3s
# 334:	total: 51s	remaining: 25.1s
# 335:	total: 51.1s	remaining: 25s
# 336:	total: 51.3s	remaining: 24.8s
# 337:	total: 51.4s	remaining: 24.6s
# 338:	total: 51.5s	remaining: 24.5s
# 339:	total: 51.7s	remaining: 24.3s
# 340:	total: 51.9s	remaining: 24.2s
# 341:	total: 52s	remaining: 24s
# 342:	total: 52.2s	remaining: 23.9s
# 343:	total: 52.3s	remaining: 23.7s
# 344:	total: 52.5s	remaining: 23.6s
# 345:	total: 52.6s	remaining: 23.4s
# 346:	total: 52.8s	remaining: 23.3s
# 347:	total: 52.9s	remaining: 23.1s
# 348:	total: 53.1s	remaining: 23s
# 349:	total: 53.2s	remaining: 22.8s
# 350:	total: 53.4s	remaining: 22.7s
# 351:	total: 53.5s	remaining: 22.5s
# 352:	total: 53.7s	remaining: 22.4s
# 353:	total: 53.9s	remaining: 22.2s
# 354:	total: 54s	remaining: 22.1s
# 355:	total: 54.2s	remaining: 21.9s
# 356:	total: 54.3s	remaining: 21.8s
# 357:	total: 54.4s	remaining: 21.6s
# 358:	total: 54.6s	remaining: 21.4s
# 359:	total: 54.7s	remaining: 21.3s
# 360:	total: 54.9s	remaining: 21.1s
# 361:	total: 55s	remaining: 21s
# 362:	total: 55.2s	remaining: 20.8s
# 363:	total: 55.3s	remaining: 20.7s
# 364:	total: 55.5s	remaining: 20.5s
# 365:	total: 55.6s	remaining: 20.4s
# 366:	total: 55.8s	remaining: 20.2s
# 367:	total: 55.9s	remaining: 20.1s
# 368:	total: 56.1s	remaining: 19.9s
# 369:	total: 56.2s	remaining: 19.8s
# 370:	total: 56.4s	remaining: 19.6s
# 371:	total: 56.5s	remaining: 19.5s
# 372:	total: 56.7s	remaining: 19.3s
# 373:	total: 56.8s	remaining: 19.1s
# 374:	total: 57s	remaining: 19s
# 375:	total: 57.1s	remaining: 18.8s
# 376:	total: 57.2s	remaining: 18.7s
# 377:	total: 57.4s	remaining: 18.5s
# 378:	total: 57.6s	remaining: 18.4s
# 379:	total: 57.7s	remaining: 18.2s
# 380:	total: 57.9s	remaining: 18.1s
# 381:	total: 58s	remaining: 17.9s
# 382:	total: 58.2s	remaining: 17.8s
# 383:	total: 58.3s	remaining: 17.6s
# 384:	total: 58.5s	remaining: 17.5s
# 385:	total: 58.6s	remaining: 17.3s
# 386:	total: 58.8s	remaining: 17.2s
# 387:	total: 58.9s	remaining: 17s
# 388:	total: 59s	remaining: 16.8s
# 389:	total: 59.2s	remaining: 16.7s
# 390:	total: 59.3s	remaining: 16.5s
# 391:	total: 59.5s	remaining: 16.4s
# 392:	total: 59.6s	remaining: 16.2s
# 393:	total: 59.8s	remaining: 16.1s
# 394:	total: 59.9s	remaining: 15.9s
# 395:	total: 1m	remaining: 15.8s
# 396:	total: 1m	remaining: 15.6s
# 397:	total: 1m	remaining: 15.5s
# 398:	total: 1m	remaining: 15.3s
# 399:	total: 1m	remaining: 15.2s
# 400:	total: 1m	remaining: 15s
# 401:	total: 1m	remaining: 14.9s
# 402:	total: 1m 1s	remaining: 14.7s
# 403:	total: 1m 1s	remaining: 14.6s
# 404:	total: 1m 1s	remaining: 14.4s
# 405:	total: 1m 1s	remaining: 14.2s
# 406:	total: 1m 1s	remaining: 14.1s
# 407:	total: 1m 1s	remaining: 13.9s
# 408:	total: 1m 1s	remaining: 13.8s
# 409:	total: 1m 2s	remaining: 13.6s
# 410:	total: 1m 2s	remaining: 13.5s
# 411:	total: 1m 2s	remaining: 13.3s
# 412:	total: 1m 2s	remaining: 13.2s
# 413:	total: 1m 2s	remaining: 13s
# 414:	total: 1m 2s	remaining: 12.9s
# 415:	total: 1m 2s	remaining: 12.7s
# 416:	total: 1m 3s	remaining: 12.6s
# 417:	total: 1m 3s	remaining: 12.4s
# 418:	total: 1m 3s	remaining: 12.3s
# 419:	total: 1m 3s	remaining: 12.1s
# 420:	total: 1m 3s	remaining: 12s
# 421:	total: 1m 3s	remaining: 11.8s
# 422:	total: 1m 4s	remaining: 11.7s
# 423:	total: 1m 4s	remaining: 11.5s
# 424:	total: 1m 4s	remaining: 11.4s
# 425:	total: 1m 4s	remaining: 11.2s
# 426:	total: 1m 4s	remaining: 11.1s
# 427:	total: 1m 4s	remaining: 10.9s
# 428:	total: 1m 4s	remaining: 10.8s
# 429:	total: 1m 5s	remaining: 10.6s
# 430:	total: 1m 5s	remaining: 10.5s
# 431:	total: 1m 5s	remaining: 10.3s
# 432:	total: 1m 5s	remaining: 10.2s
# 433:	total: 1m 5s	remaining: 10s
# 434:	total: 1m 5s	remaining: 9.86s
# 435:	total: 1m 6s	remaining: 9.71s
# 436:	total: 1m 6s	remaining: 9.56s
# 437:	total: 1m 6s	remaining: 9.41s
# 438:	total: 1m 6s	remaining: 9.26s
# 439:	total: 1m 6s	remaining: 9.11s
# 440:	total: 1m 6s	remaining: 8.95s
# 441:	total: 1m 7s	remaining: 8.8s
# 442:	total: 1m 7s	remaining: 8.65s
# 443:	total: 1m 7s	remaining: 8.5s
# 444:	total: 1m 7s	remaining: 8.35s
# 445:	total: 1m 7s	remaining: 8.2s
# 446:	total: 1m 7s	remaining: 8.04s
# 447:	total: 1m 7s	remaining: 7.89s
# 448:	total: 1m 8s	remaining: 7.74s
# 449:	total: 1m 8s	remaining: 7.59s
# 450:	total: 1m 8s	remaining: 7.44s
# 451:	total: 1m 8s	remaining: 7.29s
# 452:	total: 1m 8s	remaining: 7.13s
# 453:	total: 1m 8s	remaining: 6.98s
# 454:	total: 1m 9s	remaining: 6.83s
# 455:	total: 1m 9s	remaining: 6.68s
# 456:	total: 1m 9s	remaining: 6.53s
# 457:	total: 1m 9s	remaining: 6.38s
# 458:	total: 1m 9s	remaining: 6.23s
# 459:	total: 1m 9s	remaining: 6.07s
# 460:	total: 1m 9s	remaining: 5.92s
# 461:	total: 1m 10s	remaining: 5.77s
# 462:	total: 1m 10s	remaining: 5.62s
# 463:	total: 1m 10s	remaining: 5.46s
# 464:	total: 1m 10s	remaining: 5.31s
# 465:	total: 1m 10s	remaining: 5.16s
# 466:	total: 1m 10s	remaining: 5.01s
# 467:	total: 1m 11s	remaining: 4.86s
# 468:	total: 1m 11s	remaining: 4.71s
# 469:	total: 1m 11s	remaining: 4.55s
# 470:	total: 1m 11s	remaining: 4.4s
# 471:	total: 1m 11s	remaining: 4.25s
# 472:	total: 1m 11s	remaining: 4.11s
# 473:	total: 1m 12s	remaining: 3.95s
# 474:	total: 1m 12s	remaining: 3.8s
# 475:	total: 1m 12s	remaining: 3.65s
# 476:	total: 1m 12s	remaining: 3.5s
# 477:	total: 1m 12s	remaining: 3.34s
# 478:	total: 1m 12s	remaining: 3.19s
# 479:	total: 1m 12s	remaining: 3.04s
# 480:	total: 1m 13s	remaining: 2.89s
# 481:	total: 1m 13s	remaining: 2.73s
# 482:	total: 1m 13s	remaining: 2.58s
# 483:	total: 1m 13s	remaining: 2.43s
# 484:	total: 1m 13s	remaining: 2.28s
# 485:	total: 1m 13s	remaining: 2.13s
# 486:	total: 1m 13s	remaining: 1.97s
# 487:	total: 1m 14s	remaining: 1.82s
# 488:	total: 1m 14s	remaining: 1.67s
# 489:	total: 1m 14s	remaining: 1.52s
# 490:	total: 1m 14s	remaining: 1.37s
# 491:	total: 1m 14s	remaining: 1.22s
# 492:	total: 1m 14s	remaining: 1.06s
# 493:	total: 1m 15s	remaining: 912ms
# 494:	total: 1m 15s	remaining: 760ms
# 495:	total: 1m 15s	remaining: 608ms
# 496:	total: 1m 15s	remaining: 456ms
# 497:	total: 1m 15s	remaining: 304ms
# 498:	total: 1m 15s	remaining: 152ms
# 499:	total: 1m 16s	remaining: 0us

# %%
cat_cat = CatBoostClassifier(
    learning_rate=0.05,
    iterations=500,
    random_seed=104702016,
    eval_metric = 'AUC',
    counter_calc_method='SkipTest',
    one_hot_max_size=255
)
cat_cat.fit(
    train_set, y_train,
    cat_features=cat_feature,
    logging_level='Verbose',
)
cat_pred = cat_cat.predict_proba(test_set)
cat_output = pd.read_csv("testing-set.csv")
cat_output["deal_or_not"] = cat_pred[:, 1]
cat_output.to_csv("cat_meanencode_cv20.csv", encoding="utf-8", index=False)
# Out:
# 0.7139587749336265

# %%
train_set.columns[np.argsort(cat_cat.feature_importances_)[::-1]]
# Out:
# Index(['source1_unit_mean_target', 'people_amount', 'order_begin_duration',
#        'area', 'source_2', 'source1_source2', 'source1_source2_unit',
#        'source2_unit', 'peopleamount_price', 'sub_line', 'peopleamount_days',
#        'day_price', 'source_1', 'unit', 'home_airport', 'abroad_hour',
#        'flight_time_std', 'order_DoY', 'days', 'home_hour', 'abroad_DoY',
#        'flight_time_sum', 'home_DoY', 'airport_price', 'price',
#        'abroad_airport', 'flight_dist_min', 'airport_days', 'flight_time_max',
#        'abroad_DoM', 'begin_DoY', 'flight_time_mean', 'home_DoM',
#        'home_part_of_day', 'flight_dist_sum', 'flight_dist_max', 'order_month',
#        'source1_unit', 'home_DoW', 'flight_time_min', 'begin_month',
#        'abroad_part_of_day', 'flight_dist_mean', 'begin_DoW',
#        'flight_dist_std', 'abroad_DoW', 'begin_quarter', 'order_quarter',
#        'airport_amount', 'subline_area', 'order_year'],
#       dtype='object')
